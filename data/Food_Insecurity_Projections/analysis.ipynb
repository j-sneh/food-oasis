# %%
import pandas as pd
from scipy.stats import norm
import numpy as np
import matplotlib.pyplot as plt
df = pd.read_excel("VLFScounties.xlsx")
print(df)
# Out:
#                                       About this file  \
# 0   This file contains 2019 historical very low fo...
# 1                                                 NaN
# 2                                                 NaN
# 3                                     Version/Updates
# 4   This file (dated 4.12.21) replaces all previou...
# 5                                                 Tab
# 6                                              County
# 7                                            District
# 8                                               State
# 9                 Feeding America Member Service Area
# 10                                                NaN
# 11                                           Variable
# 12                                   Total Population
# 13                      2019 Very Low Food Security %
# 14                      2019 Very Low Food Security #
# 15  [Revised Projections – March 2021] 2020/2021 V...
# ...

# %%
s = df.sort_values(['State','2020_VLFS_Percent_Mar2021']).groupby('State').head(10).reset_index()
print(s)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /var/folders/rw/_898b6y93wqd67qwd26qf_k40000gn/T/ipykernel_73525/2366022156.py in <module>
# ----> 1 s = df.sort_values(['State','2020_VLFS_Percent_Mar2021']).groupby('State').head(10).reset_index()
#       2 print(s)
#
# /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/pandas/util/_decorators.py in wrapper(*args, **kwargs)
#     309                     stacklevel=stacklevel,
#     310                 )
# --> 311             return func(*args, **kwargs)
#     312
#     313         return wrapper
#
# /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/pandas/core/frame.py in sort_values(self, by, axis, ascending, inplace, kind, na_position, ignore_index, key)
#    6235         if len(by) > 1:
#    6236
# ...
